# %%
from dotenv import load_dotenv
import os
from groq import Groq


load_dotenv()
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

chat_completion = client.chat.completions.create(
    messages=[
        {"role": "user", "content": "Explain the importance of fast language models"}
    ],
    model="openai/gpt-oss-120b",
    temperature=0
)

print(chat_completion.choices[0].message.content)
# Out:
# ## Why Speed Matters for Language Models
#
# | **Domain** | **Why Low Latency Is Critical** | **What Happens If the Model Is Too Slow** |
# |------------|--------------------------------|-------------------------------------------|
# | **Interactive AI (chatbots, virtual assistants)** | Users expect answers in < 1 s; otherwise they abandon the conversation. | Stilted, “thinking” pauses break the flow and reduce trust. |
# | **Search & Retrieval** | Ranking or query‑expansion must happen while the user is still looking at the results page. | Delayed results lower click‑through rates and hurt revenue. |
# | **Real‑time Translation / Speech‑to‑Text** | Speech streams continuously; a 200 ms lag is already noticeable. | Missed words, garbled output, and a poor user experience. |
# | **Robotics & Autonomous Systems** | Decisions must be made within milliseconds to avoid collisions. | Safety hazards, failed missions, or costly downtime. |
# | **Edge Devices (phones, wearables, IoT)** | Limited compute, battery, and network bandwidth. | Heavy models drain battery, require cloud calls, and increase latency. |
# | **Enterprise Workflows (document processing, code generation)** | Batch jobs may be large; faster inference reduces total processing time and cost. | Higher cloud‑compute bills, slower pipelines, and delayed time‑to‑value. |
# | **Research & Development** | Faster inference enables rapid prototyping, hyper‑parameter sweeps, and large‑scale experiments. | Slower iteration cycles, higher research overhead. |
#
# In short, **speed directly translates into better user experience, lower operational cost, higher safety, and greater scalability**.
#
# ---
#
# ## 1. Technical Drivers of Speed
#
# ### 1.1 Model Architecture & Size
# - **Parameter count**: Larger models (e.g., GPT‑4‑XL) have more FLOPs per token, increasing latency.
# - **Depth vs. width**: Deeper transformers incur more sequential operations; wider but shallower models can be more parallelizable.
#
# ### 1.2 Hardware Utilization
# - **GPU/TPU parallelism**: Exploiting tensor cores, mixed‑precision (FP16/BF16) reduces compute time.
# - **CPU inference**: Critical for edge; requires models that fit in cache and use SIMD/AVX instructions.
# - **Specialized ASICs**: e.g., NVIDIA LLM‑optimized chips, Graphcore IPUs, or custom inference accelerators.
#
# ### 1.3 Software Optimizations
# - **Kernel fusion**: Merges multiple matrix‑multiply + activation steps into a single kernel.
# - **Operator caching & pre‑allocation**: Avoids repeated memory allocation.
# - **Dynamic batching & request routing**: Packs multiple user queries into one batch to improve throughput without hurting per‑request latency.
#
# ### 1.4 Model Compression Techniques
# | Technique | How It Speeds Up Inference | Typical Trade‑off |
# |-----------|----------------------------|-------------------|
# | **Quantization** (e.g., 8‑bit, 4‑bit) | Reduces memory bandwidth and enables integer matrix multiplies. | Small loss in perplexity/accuracy; sometimes mitigated with fine‑tuning. |
# | **Pruning** (structured/unstructured) | Removes redundant weights → fewer FLOPs. | May require retraining; can hurt performance if over‑pruned. |
# | **Knowledge Distillation** | Trains a smaller “student” model to mimic a larger “teacher”. | Student often matches teacher on many tasks, but may lag on edge cases. |
# | **Low‑rank factorization** | Decomposes weight matrices into products of smaller matrices. | Slight accuracy drop; can be combined with quantization. |
# | **Sparse Transformers** (e.g., Longformer, BigBird) | Compute only a subset of attention scores. | Works well for long‑context tasks; not always beneficial for short inputs. |
#
# ---
#
# ## 2. Business & Economic Impact
#
# | **Metric** | **Effect of Faster Models** | **Quantitative Example** |
# |------------|----------------------------|--------------------------|
# | **User Retention** | Faster responses keep users engaged. | A 100 ms reduction in chatbot latency can increase conversion by ~5 % (per internal A/B tests at several SaaS firms). |
# | **Compute Cost** | Lower FLOPs per token → cheaper cloud GPU usage. | 8‑bit quantized inference can cut GPU‑hour cost by 2–3× for the same throughput. |
# | **Energy Consumption** | Less compute → lower power draw, greener operations. | A 30 % latency reduction on a 10 B‑parameter model saves ~0.5 kWh per million tokens processed. |
# | **Time‑to‑Market** | Faster prototyping accelerates product launches. | Teams using distilled models can iterate 3× faster than those stuck on full‑size models. |
# | **Regulatory & Safety** | Real‑time decision making is often a compliance requirement (e.g., medical triage). | Latency < 200 ms is mandated for some FDA‑approved AI diagnostic tools. |
#
# ---
#
# ## 3. Real‑World Use Cases
#
# ### 3.1 Customer‑Facing Chatbots
# - **Scenario**: A retail website uses a conversational assistant to answer product questions.
# - **Speed Requirement**: ≤ 500 ms end‑to‑end (including network).
# - **Solution**: Deploy a 2‑B‑parameter distilled model quantized to 4‑bit on a GPU‑accelerated inference server; use a lightweight routing layer to batch requests.
#
# ### 3.2 Voice‑Activated Smart Speakers
# - **Scenario**: Wake‑word detection → speech‑to‑text → language model for intent.
# - **Speed Requirement**: < 150 ms from utterance end to response.
# - **Solution**: Run a 300 M‑parameter model on an on‑device NPU with 8‑bit quantization; fallback to cloud for complex queries.
#
# ### 3.3 Real‑Time Code Completion (e.g., GitHub Copilot)
# - **Scenario**: Developer types; model suggests next line.
# - **Speed Requirement**: < 200 ms to keep the IDE fluid.
# - **Solution**: Use a hybrid approach: a small “draft” model runs locally for instant suggestions; a larger model runs in the cloud for higher‑quality completions that appear a second later.
#
# ### 3.4 Large‑Scale Document Processing (Legal, Finance)
# - **Scenario**: Process millions of contracts nightly to extract clauses.
# - **Speed Requirement**: Throughput > 10 k documents/minute, latency per document < 2 s.
# - **Solution**: Parallelize across a GPU cluster, use mixed‑precision inference, and apply model parallelism only for the largest models; otherwise, use a distilled 1‑B‑parameter model.
#
# ---
#
# ## 4. How to Build Faster Language Models
#
# 1. **Start with the Right Baseline**
#    - Choose a model size that meets accuracy needs *and* fits the target hardware.
#    - For edge, consider models designed for efficiency (e.g., LLaMA‑Adapter, TinyBERT, DistilGPT).
#
# 2. **Apply Quantization Early**
#    - Use post‑training static quantization (INT8) for a quick win.
#    - If you need more compression, explore **GPTQ** or **AWQ** for 4‑bit inference.
#
# 3. **Distill When Possible**
#    - Train a student model on the teacher’s logits + hard labels.
#    - Use **teacher‑forced** and **self‑distillation** to preserve performance on downstream tasks.
#
# 4. **Leverage Sparse Attention for Long Context**
#    - If your workload involves > 4 k tokens (e.g., document summarization), switch to a sparse transformer variant to cut attention cost from O(N²) to O(N·√N) or O(N·log N).
#
# 5. **Optimize the Serving Stack**
#    - Use **TensorRT**, **ONNX Runtime**, or **vLLM** for high‑throughput serving.
#    - Enable **dynamic batching** and **prefill‑decode** pipelines (e.g., FlashAttention‑2) to reduce per‑token overhead.
#
# 6. **Profile End‑to‑End Latency**
#    - Measure not just GPU compute time but also tokenization, network, and post‑processing.
#    - Identify bottlenecks with tools like **NVIDIA Nsight**, **PyTorch Profiler**, or **OpenTelemetry**.
#
# 7. **Iterate on the Trade‑off Curve**
#    - Plot **accuracy vs. latency** for several compression levels.
#    - Pick the “knee” point where a small loss in quality yields a large latency gain.
#
# ---
#
# ## 5. Future Directions
#
# | **Trend** | **Potential Speed Gains** | **Open Challenges** |
# |-----------|---------------------------|---------------------|
# | **Mixture‑of‑Experts (MoE) Transformers** | Activate only a subset of expert layers → up to 4× faster for the same parameter count. | Routing overhead, load balancing, and inference‑time memory spikes. |
# | **Neural Architecture Search (NAS) for LLMs** | Auto‑discover ultra‑efficient attention patterns. | Search cost is high; need transferability across tasks. |
# | **Hardware‑Model Co‑Design** | ASICs that natively support 4‑bit or 2‑bit matrix ops. | Ecosystem maturity, software tooling, and portability. |
# | **Cache‑Based Retrieval‑Augmented Generation** | Offload long‑context reasoning to a vector store; LLM only generates. | Retrieval latency, consistency between retrieved docs and generated text. |
# | **Continual Compression** | Dynamically switch precision per token (e.g., high‑precision for rare words). | Complexity in runtime scheduling and potential jitter. |
#
# ---
#
# ## 6. TL;DR Summary
#
# - **Fast language models are essential** for any scenario where users or systems cannot wait—chat, search, translation, robotics, edge devices, and large‑scale batch pipelines.
# - Speed improves **user satisfaction, safety, cost efficiency, and scalability**.
# - Achieving speed involves a **holistic approach**: choosing the right model size, compressing (quantization, pruning, distillation), exploiting hardware (GPUs, TPUs, ASICs), and optimizing the serving stack (kernel fusion, dynamic batching).
# - The **trade‑off** between latency and accuracy must be measured and tuned for each product.
# - Ongoing research (MoE, NAS, retrieval‑augmented generation) promises even faster inference, but practical deployment still hinges on solid engineering and profiling.
#
# By treating latency as a first‑class metric—just like accuracy—you can deliver AI experiences that are **responsive, affordable, and safe**, unlocking the full commercial and societal value of large language models.

# %%
class Agent:
    def __init__(self, client, system):
        self.client = client
        self.system = system
        self.messages = []
        if self.system is not None:
            self.messages.append({"role": "system", "content": self.system})

    def __call__(self, message):
        if message:
            self.messages.append({"role": "user", "content": message})
        result = self.execute()
        self.messages.append({"role": "assistant", "content": result})
        return result

    def execute(self):
        completion = client.chat.completions.create(
            messages=self.messages,
            model="llama-3.1-8b-instant",
        )
        return completion.choices[0].message.content

# %%
system_prompt = """
You run in a loop of Thought, Action, PAUSE, Observation.
At the end of the loop you output an Answer
Use Thought to describe your thoughts about the question you have been asked.
Use Action to run one of the actions available to you - then return PAUSE.
Observation will be the result of running those actions.

Your available actions are:

calculate:
e.g. calculate: 4 * 7 / 3
Runs a calculation and returns the number - uses Python so be sure to use floating point syntax if necessary

get_planet_mass:
e.g. get_planet_mass: Earth
returns weight of the planet in kg

Example session:

Question: What is the mass of Earth times 2?
Thought: I need to find the mass of Earth
Action: get_planet_mass: Earth
PAUSE 

You will be called again with this:

Observation: 5.972e24

Thought: I need to multiply this by 2
Action: calculate: 5.972e24 * 2
PAUSE

You will be called again with this: 

Observation: 1,1944×10e25

If you have the answer, output it as the Answer.

Answer: The mass of Earth times 2 is 1,1944×10e25.

Now it's your turn:
""".strip()

# %%
def calculate(operation: str) -> float:
    return eval(operation)

 
def get_planet_mass(planet) -> float:
    if planet == "earth":
        return 5.972e24
    if planet == "mars":
        return 6.39e23
    if planet == "jupiter":
        return 1.898e27
    if planet == "saturn":
        return 5.683e26
    if planet == "uranus":
        return 8.681e25
    if planet == "neptune":
        return 1.024e26
    if planet == "mercury":
        return 3.285e23
    if planet == "venus":
        return 4.867e24
    return None

# %%
neil_tyson = Agent(client,system_prompt)
result = neil_tyson("what is the mass of earth times 5")
print(result)
# Out:
# Thought: I need to find the mass of Earth, and then multiply it by 5
#
# Action: get_planet_mass: Earth
# PAUSE
